# %%
# Import packages
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.io import fits
from astropy.wcs import WCS

import os, sys
sys.path.append('/home/jiaxuanl/Research/SALAD/script/')
import kuaizi
from kuaizi.display import display_single
kuaizi.set_env(project='SBF', name='Rosesim', data_dir='/scratch/gpfs/JENNYG/jiaxuanl/Data')
# kuaizi.set_matplotlib(style='JL', usetex=True, fontsize=18, figsize=(7, 5), dpi=90)
# Out:
# '/scratch/gpfs/JENNYG/jiaxuanl/Data/SBF/Rosesim'

# %%
import asdf
from astroquery.gaia import Gaia
from astropy.coordinates import SkyCoord
from astropy.time import Time
from astropy.table import Table, vstack
from astropy import units as u
from astropy.visualization import simple_norm
import copy
import galsim
import roman_datamodels as rdm
from romanisim import gaia, bandpass, catalog, log, wcs, persistence, parameters, ris_make_utils as ris
from romanisim.image import inject_sources_into_l2
from romanisim.l3 import inject_sources_into_l3

# %%
norm = simple_norm(dm.data, 'asinh', percent=99.7)
plt.imshow(dm.data[900:1100, 900:1100], norm=norm, cmap='afmhot', origin='lower',
           # extent=[900, 1100, 900, 1100]
          );

# %% [markdown]
# ## Artpop and make catalogs

# %%
import artpop
sys.path.append('/home/jiaxuanl/Research/SBF/src/SBF')
import rosesim
from rosesim import RomanGalaxy, rng
from astropy.table import Column, hstack, vstack

# %%
# obs_ra = 270.95
# obs_dec = -0.19
obs_ra = 150.1049 #270.95
obs_dec = 2.2741 # -0.2

# %%
log_m_star = 8 #4
gal_kwargs = {'age': 0.4 * u.Gyr,
              'feh': -1.5,
              'total_mass': 10**log_m_star,
              'r_eff': 10**rosesim.mass_size_carlsten(log_m_star) / 1000 * u.kpc,
              'distance': 50 * u.Mpc}
gal = RomanGalaxy(prefix=f'ufd_1e{log_m_star}_{int(gal_kwargs["distance"].to(u.Mpc).value)}Mpc_{gal_kwargs["age"].value}Gyr')

# %%
print('R_eff [arcsec]', (gal_kwargs['r_eff'] / gal_kwargs['distance']).cgs * 206265)
# Out:
# R_eff [arcsec] 4.59679923942596

# %%
src = artpop.MISTSersicSSP(
    log_age=np.log10(gal_kwargs['age'].to(u.yr).value),        # log of age in years
    feh=gal_kwargs['feh'],           # metallicity [Fe/H]
    r_eff=gal_kwargs['r_eff'],
    n=0.8, 
    theta=135 * u.deg,
    ellip=0.3,
    total_mass=gal_kwargs['total_mass'],
    mag_limit=27.0,# + 3.5, #38, #36,
    mag_limit_band='H158',
    phot_system='WFIRST', # in vega
    distance=gal_kwargs['distance'], # distance to system
    xy_dim=1001,
    pixel_scale=0.11,    # pixel scale in arcsec / pixel
    random_state=rng,   # random state for reproducibility
)
print('# of stars', src.num_stars)
print('Sampled mass fraction:', src.sp.sampled_mass / src.sp.total_mass)
# convert Vega to AB
for filt in src.mags.colnames:
    src.mags[filt] += rosesim.mist_vega_to_ab[filt]
# Out:
# # of stars 3496
# Sampled mass fraction: 8.554403855780007e-05

# %%
print('Total mag from stars', -2.5 * np.log10(np.sum(10**(-0.4 * src.mags['H158']))))
print('Total mag fron smooth', src.sp.mag_integrated_component('H158'))
print('SB of smooth', src.sp.mag_integrated_component('H158') + 2.5 * np.log10(2 * np.pi * src.smooth_model.r_eff.value**2 * 0.11**2))
# Out:
# Total mag from stars 18.615660721568194
# Total mag fron smooth 15.847033630136789
# SB of smooth 21.154758944874786

# %%
gal.load_src(src, ra=obs_ra, dec=obs_dec)
gal.load_gaia_star()
gal.load_cosmos_bkg(seed=12)
gal.gen_catalog(include_gaia=True, include_bkg=True)
# Out:
# 2025-08-12 04:19:06 INFO     Query finished.
# INFO: Query finished. [astroquery.utils.tap.core]
# 0 Gaia stars loaded.
# 520 background galaxies loaded.
# Catalogue generated.

# %%
import os
os.environ['NUMEXPR_MAX_THREADS'] = "30"

# %%
for filt in ['F106', 'F129', 'F158']:
    gal.observe(filt)
# Out:
# Making mock Roman L3 image in F106 for ufd_1e8_50Mpc_0.4Gyr
# 2025-08-12 04:26:02 INFO     Starting simulation...
# 2025-08-12 04:26:02 WARNING  romanisim is under active development.  Its output has not been formally validated; only limited testing has been performed.  For this reason, use of romanisim for preparation of ROSES proposals is not advised.  Other packages like galsim's roman package or STIPS may better serve such purposes.
# 2025-08-12 04:26:02 INFO     Setting WCS reference to RA_ref=150.1049, Dec_ref=2.2741
# 2025-08-12 04:26:02 INFO     Simulating filter F106...
# 2025-08-12 04:26:03 INFO     Setting pixscale to match default.
# 2025-08-12 04:26:03 WARNING  wcs is None; unlikely to get orientation of PSF correct.
# 2025-08-12 04:26:04 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2025-08-12 04:26:04 INFO     Using pupil mask 'F062' and detector 'WFI02'.
# 2025-08-12 04:26:04 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2025-08-12 04:26:04 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2025-08-12 04:26:04 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2025-08-12 04:26:04 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2025-08-12 04:26:04 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2025-08-12 04:26:04 INFO     Creating optical system model:
# 2025-08-12 04:26:04 INFO     Initialized OpticalSystem: Roman+WFI
# 2025-08-12 04:26:04 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/jiaxuanl/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI02.fits.gz
# 2025-08-12 04:26:04 INFO     Roman Entrance Pupil: Loaded OPD from /home/jiaxuanl/data/stpsf-data/upscaled_HST_OPD.fits
# 2025-08-12 04:26:04 INFO     Added pupil plane: Roman Entrance Pupil
# 2025-08-12 04:26:04 INFO     Added coordinate inversion plane: OTE exit pupil
# 2025-08-12 04:26:04 INFO     Added pupil plane: Field Dependent Aberration (WFI02)
# 2025-08-12 04:26:04 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2025-08-12 04:26:04 INFO     Calculating PSF with 10 wavelengths
# 2025-08-12 04:26:04 INFO      Propagating wavelength = 9.4555e-07 m
# 2025-08-12 04:26:09 INFO      Propagating wavelength = 9.7265e-07 m
# 2025-08-12 04:26:09 INFO      Propagating wavelength = 9.9975e-07 m
# 2025-08-12 04:26:10 INFO      Propagating wavelength = 1.02685e-06 m
# 2025-08-12 04:26:10 INFO      Propagating wavelength = 1.05395e-06 m
# 2025-08-12 04:26:11 INFO      Propagating wavelength = 1.08105e-06 m
# 2025-08-12 04:26:11 INFO      Propagating wavelength = 1.10815e-06 m
# 2025-08-12 04:26:12 INFO      Propagating wavelength = 1.13525e-06 m
# 2025-08-12 04:26:12 INFO      Propagating wavelength = 1.16235e-06 m
# 2025-08-12 04:26:13 INFO      Propagating wavelength = 1.18945e-06 m
# 2025-08-12 04:26:13 INFO       Calculation completed in 8.993 s
# 2025-08-12 04:26:13 INFO     PSF Calculation completed.
# 2025-08-12 04:26:13 INFO     Calculating jitter using gaussian
# 2025-08-12 04:26:13 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2025-08-12 04:26:13 INFO             resulting image peak drops to 0.946 of its previous value
# 2025-08-12 04:26:13 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2025-08-12 04:26:13 INFO      Adding extension with image downsampled to detector pixel scale.
# 2025-08-12 04:26:13 INFO      Downsampling to detector pixel scale, by 4
# 2025-08-12 04:26:13 INFO      Downsampling to detector pixel scale, by 4
# 2025-08-12 04:26:15 INFO     Adding 4017 sources to image...
# 2025-08-12 04:27:51 INFO     Rendered 4017 sources...
# 2025-08-12 04:27:52 INFO     Simulation complete.
# Making mock Roman L3 image in F129 for ufd_1e8_50Mpc_0.4Gyr
# 2025-08-12 04:27:56 INFO     Starting simulation...
# 2025-08-12 04:27:56 WARNING  romanisim is under active development.  Its output has not been formally validated; only limited testing has been performed.  For this reason, use of romanisim for preparation of ROSES proposals is not advised.  Other packages like galsim's roman package or STIPS may better serve such purposes.
# 2025-08-12 04:27:56 INFO     Setting WCS reference to RA_ref=150.1049, Dec_ref=2.2741
# 2025-08-12 04:27:56 INFO     Simulating filter F129...
# 2025-08-12 04:27:57 INFO     Setting pixscale to match default.
# 2025-08-12 04:27:57 WARNING  wcs is None; unlikely to get orientation of PSF correct.
# 2025-08-12 04:27:58 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2025-08-12 04:27:58 INFO     Using pupil mask 'F062' and detector 'WFI02'.
# 2025-08-12 04:27:58 INFO     Using pupil mask 'F129' and detector 'WFI02'.
# 2025-08-12 04:27:58 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2025-08-12 04:27:58 INFO     Computing wavelength weights using synthetic photometry for F129...
# 2025-08-12 04:27:58 INFO     Using pupil mask 'F129' and detector 'WFI02'.
# 2025-08-12 04:27:58 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2025-08-12 04:27:58 INFO     Creating optical system model:
# 2025-08-12 04:27:58 INFO     Initialized OpticalSystem: Roman+WFI
# 2025-08-12 04:27:59 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/jiaxuanl/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F129_WFI02.fits.gz
# 2025-08-12 04:27:59 INFO     Roman Entrance Pupil: Loaded OPD from /home/jiaxuanl/data/stpsf-data/upscaled_HST_OPD.fits
# 2025-08-12 04:27:59 INFO     Added pupil plane: Roman Entrance Pupil
# 2025-08-12 04:27:59 INFO     Added coordinate inversion plane: OTE exit pupil
# 2025-08-12 04:27:59 INFO     Added pupil plane: Field Dependent Aberration (WFI02)
# 2025-08-12 04:27:59 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2025-08-12 04:27:59 INFO     Calculating PSF with 10 wavelengths
# 2025-08-12 04:27:59 INFO      Propagating wavelength = 1.1425e-06 m
# 2025-08-12 04:28:03 INFO      Propagating wavelength = 1.1755e-06 m
# 2025-08-12 04:28:04 INFO      Propagating wavelength = 1.2085e-06 m
# 2025-08-12 04:28:04 INFO      Propagating wavelength = 1.2415e-06 m
# 2025-08-12 04:28:05 INFO      Propagating wavelength = 1.2745e-06 m
# 2025-08-12 04:28:05 INFO      Propagating wavelength = 1.3075e-06 m
# 2025-08-12 04:28:06 INFO      Propagating wavelength = 1.3405e-06 m
# 2025-08-12 04:28:06 INFO      Propagating wavelength = 1.3735e-06 m
# 2025-08-12 04:28:07 INFO      Propagating wavelength = 1.4065e-06 m
# 2025-08-12 04:28:08 INFO      Propagating wavelength = 1.4395e-06 m
# 2025-08-12 04:28:08 INFO       Calculation completed in 9.474 s
# 2025-08-12 04:28:08 INFO     PSF Calculation completed.
# 2025-08-12 04:28:08 INFO     Calculating jitter using gaussian
# 2025-08-12 04:28:08 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2025-08-12 04:28:08 INFO             resulting image peak drops to 0.961 of its previous value
# 2025-08-12 04:28:08 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2025-08-12 04:28:08 INFO      Adding extension with image downsampled to detector pixel scale.
# 2025-08-12 04:28:08 INFO      Downsampling to detector pixel scale, by 4
# 2025-08-12 04:28:08 INFO      Downsampling to detector pixel scale, by 4
# 2025-08-12 04:28:10 INFO     Adding 4017 sources to image...
# 2025-08-12 04:29:24 INFO     Rendered 4017 sources...
# 2025-08-12 04:29:24 INFO     Simulation complete.
# Making mock Roman L3 image in F158 for ufd_1e8_50Mpc_0.4Gyr
# 2025-08-12 04:29:28 INFO     Starting simulation...
# 2025-08-12 04:29:28 WARNING  romanisim is under active development.  Its output has not been formally validated; only limited testing has been performed.  For this reason, use of romanisim for preparation of ROSES proposals is not advised.  Other packages like galsim's roman package or STIPS may better serve such purposes.
# 2025-08-12 04:29:28 INFO     Setting WCS reference to RA_ref=150.1049, Dec_ref=2.2741
# 2025-08-12 04:29:28 INFO     Simulating filter F158...
# 2025-08-12 04:29:29 INFO     Setting pixscale to match default.
# 2025-08-12 04:29:29 WARNING  wcs is None; unlikely to get orientation of PSF correct.
# 2025-08-12 04:29:30 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2025-08-12 04:29:30 INFO     Using pupil mask 'F062' and detector 'WFI02'.
# 2025-08-12 04:29:30 INFO     Using pupil mask 'F158' and detector 'WFI02'.
# 2025-08-12 04:29:30 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2025-08-12 04:29:30 INFO     Computing wavelength weights using synthetic photometry for F158...
# 2025-08-12 04:29:30 INFO     Using pupil mask 'F158' and detector 'WFI02'.
# 2025-08-12 04:29:30 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2025-08-12 04:29:30 INFO     Creating optical system model:
# 2025-08-12 04:29:30 INFO     Initialized OpticalSystem: Roman+WFI
# 2025-08-12 04:29:30 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/jiaxuanl/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F158_WFI02.fits.gz
# 2025-08-12 04:29:31 INFO     Roman Entrance Pupil: Loaded OPD from /home/jiaxuanl/data/stpsf-data/upscaled_HST_OPD.fits
# 2025-08-12 04:29:31 INFO     Added pupil plane: Roman Entrance Pupil
# 2025-08-12 04:29:31 INFO     Added coordinate inversion plane: OTE exit pupil
# 2025-08-12 04:29:31 INFO     Added pupil plane: Field Dependent Aberration (WFI02)
# 2025-08-12 04:29:31 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2025-08-12 04:29:31 INFO     Calculating PSF with 10 wavelengths
# 2025-08-12 04:29:31 INFO      Propagating wavelength = 1.40235e-06 m

# %%
# with asdf.open('./out.asdf', 'rb') as fb:
af = asdf.open('./l3.asdf')
dm = rdm.open(af)
dm.meta.wcs = wcs.get_mosaic_wcs(dm)
hdr = dm.meta.wcs.to_fits(((0, gal.xy_dim[0]), (0, gal.xy_dim[1])))
img = dm.data
img -= 1.956
fits.PrimaryHDU(data=img, header=fits.Header(hdr[0])).writeto('./test.fits', overwrite=True)

# %%
display_single(img, contrast=0.1);

# %% [markdown]
# # Visualize

# %%
# wid = 150
# name = gal.prefix #'dwarf_1e6_20Mpc' #gal.prefix
# # filt_idx = [0, 1, 2]
# filt_idx = [1, 2, 3]
# imgs = [fits.open(f'./{name}_1_{i}.fits')[1].data[2044 - wid:2044 + wid, 2044 - wid:2044 + wid] - 0.3 for i in filt_idx]

# %%
from astropy.visualization import make_lupton_rgb

# %%
zp = -2.5 * np.log10(1 * ((0.11 * u.arcsec)**2).to(u.steradian).value * 1e6 / 3631)

# %%
filters = ['F106', 'F129', 'F158']
imgs = []
for filt in filters:
    af = asdf.open(f'./{filt}_3000s.asdf')
    dm = rdm.open(af)
    img = dm.data - np.median(dm.data)
    img *= 10**(0.4 * (27 - zp))
    imgs.append(img[:, :])

# %%
rgb = make_lupton_rgb(1.0 * imgs[2], 1.05 * imgs[1], 1.2 * imgs[0], minimum=0, stretch=1, Q=3)
fig, ax = plt.subplots(figsize=(12, 12))
plt.imshow(rgb)
plt.axis('off')

# plt.text(wid - 0.2 * wid, +5, filters[filt_idx[0]], 
         # fontsize=20, color='deepskyblue', va='center', ha='center')
# plt.text(wid, +5, filters[filt_idx[1]], 
         # fontsize=20, color='limegreen', va='center', ha='center')
# plt.text(wid + 0.2 * wid, +5, filters[filt_idx[2]], 
         # fontsize=20, color='orangered', va='center', ha='center')
title = '$\mathrm{Age} = ' + f'{gal_kwargs["age"].to(u.Gyr).value:.1f}' + '\ \mathrm{Gyr}$, '
title += '$\mathrm{[Fe/H]}=' + f'{gal_kwargs["feh"]:.1f}' + '$, '
title += '$M_\star=10^{' + f'{np.log10(gal_kwargs["total_mass"]):.1f}' + '}\ M_\odot$, '
title += '$D=' + str(int(gal_kwargs['distance'].to(u.Mpc).value)) + '$ Mpc'
plt.title(title, fontsize=20)

plt.savefig('/tigress/jiaxuanl/public_html/figure/SBF/Rosesim/dwarf4.png', bbox_inches='tight', dpi=200)

# %%
from display import show_image_wcs

# %%
rgb = make_lupton_rgb(0.8 * obs_i, obs_r, 1.05 * obs_g, minimum=0, stretch=1, Q=5)
fig, ax = plt.subplots(figsize=(10, 10))
artpop.show_image(rgb, subplots=(fig, ax));
plt.axis('off')

plt.title('$\mathrm{Age} = 0.5\ \mathrm{Gyr}$, $\mathrm{[Fe/H]}=-0.5$, $M_\star=10^{7}\ M_\odot$, $D=10$ Mpc')

# plt.savefig('/tigress/jiaxuanl/public_html/figure/SBF/stips_dwarf.png', bbox_inches='tight')
